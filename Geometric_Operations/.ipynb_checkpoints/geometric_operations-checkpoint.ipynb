# %% [markdown]
# # Geometric functions
#
# ### Tópics:
#
# **1.** *Shift (Translation);*
#
# **2.** *Rotation;*

# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Original image

# %%
# global variables
absolute_path = os.path.join(os.path.dirname(os.getcwd()), 'imgs', 'cube.jpg');

# loading the image
img = cv2.imread(absolute_path,0)

plt.figure(1,figsize=(15,5))
plt.subplot(121)
plt.title("grayscale")
plt.imshow(img, cmap='gray')

img_rgb = cv2.imread(absolute_path,1)
plt.subplot(122)
plt.title("rgb")
plt.imshow(cv2.cvtColor(img_rgb, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Function definition

# %%
# x = horizontal
# y = vertical

def geometry(img, translation, multiplication, circular=False, rescale=False):
    # circulate does the pixels apear in the other side of the image
    # J(x,y) = I((x+x_sum)*x_multiply, (y+y_sum)*y_multiply)

    x_sum,  y_sum  = translation
    x_mult, y_mult = multiplication

    height, width = img.shape
    if rescale:
        height = height/y_scale
        width  = width/x_scale

    J = np.zeros((height, width))

    for x in range(len(J)):
        for y in range(len(J[x])):
            reference_x = (x+x_sum)*x_mult
            reference_y = (y+y_sum)*y_mult
            
            if not circular:
                reference_x = None if reference_x < 0 else reference_x
                reference_y = None if reference_y < 0 else reference_y
            
            reference_x = None if reference_x > height-1 else reference_x
            reference_y = None if reference_y > width-1  else reference_y
            
            J[x][y] = img[reference_x][reference_y] if reference_x and reference_y else 0

    return J

# %% [markdown]
# ## Translation test

# %%
plt.figure(1,figsize=(15,15))

plt.subplot(221)
plt.title("With rotation")
plt.imshow(geometry(img, (-100,-100), (1,1), True, False), cmap='gray')

plt.subplot(222)
plt.title("Without rotation")
plt.imshow(geometry(img, (-100,-100), (1,1), False, False), cmap='gray')

plt.subplot(223)
plt.imshow(geometry(img, (100,100), (1,1), True, False), cmap='gray')

plt.subplot(224)
plt.imshow(geometry(img, (100,100), (1,1), False, False), cmap='gray')

plt.show()

# %%
    for x in range(len(img)):
        for y in range(len(img[x])):
            reference_x = x+x_translate
            reference_y = y+y_translate
            
            if circulate:
                reference_x = len(img)    - reference_x if reference_x > len(img)-1    else reference_x
                reference_y = len(img[x]) - reference_y if reference_y > len(img[x])-1 else reference_y
                new_value = img[reference_x][reference_y]
            else:
                if (reference_x > -1 and reference_y > -1) and (reference_x < len(img) and reference_y < len(img[x])):
                    new_value = img[reference_x][reference_y]
                else:
                    new_value = 0

            J[x][y] = new_value
# Out:
# (500, 500)
